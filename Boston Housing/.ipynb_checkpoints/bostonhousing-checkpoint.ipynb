# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

df = pd.read_csv("BostonHousing") #Set 1 Question 1

# %%
nrows=df.shape[0]  #Set 1 Question 2
ncolumns=df.shape[1]
print("Number of rows: "+str(nrows))
print("Number of  columns: "+str(ncolumns))
# Out:
# Number of rows: 506
# Number of  columns: 14

# %%
print(list(df.columns))  #Set 1 Question 3
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'LSTAT', 'MEDV', 'CAT.MEDV']

# %%
df.head(5) #Set 1 Question 4
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT.MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# 3   2.94  33.4         1
# 4   5.33  36.2         1

# %%
df.tail(5) #Set 1 Question 5
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#      LSTAT  MEDV  CAT.MEDV
# 501   9.67  22.4         0
# 502   9.08  20.6         0
# 503   5.64  23.9         0
# 504   6.48  22.0         0
# 505   7.88  11.9         0

# %%
df.head(10) #Set 1 Question 6
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  CAT.MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# ...

# %%
df.describe() #Set 1 Question 7
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
df['CHAS'].value_counts() #Set 1 Question 8
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
df['CAT.MEDV'].value_counts() #Set 1 Question 9
# Out:
# 0    422
# 1     84
# Name: CAT.MEDV, dtype: int64

# %%
df.groupby('CHAS',as_index=False)['MEDV'].mean() #Set 1 Question 10
# Out:
#    CHAS       MEDV
# 0     0  22.093843
# 1     1  28.440000

# %%
df.groupby('CHAS',as_index=False)['MEDV'].median()  #Set 1 Question 11
# Out:
#    CHAS  MEDV
# 0     0  20.9
# 1     1  23.3

# %%
print(df.plot(x='LSTAT',y='MEDV',style='o')) #Set 1 Question 12
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.hist('MEDV') #Set 1 Question 13
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6e975771d0>]],
#       dtype=object)

# %%
sns.boxplot(x='CHAS',y='MEDV',data=df) #Set 1 Question 14

# %%
sns.boxplot(x='CAT.MEDV',y='LSTAT',data=df) #Set 1 Question 15

# %%
scp=sns.pairplot(df) #Set 1 Question 16

# %%
sns.scatterplot(x='CRIM',y='MEDV',data=df) #Set 1 Question 17

# %%
sns.scatterplot(x='CRIM',y='MEDV',data=np.log(df)) #Set 1 Question 18
# Out:
# /home/arjun/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
df[3:5] #Set 2 Question 1
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 3  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT.MEDV
# 3   2.94  33.4         1
# 4   5.33  36.2         1

# %%
df.sort_values('MEDV')  #Set 2 Question 2
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 398  38.35180   0.0  18.10     0  0.6930  5.453  100.0  1.4896   24  666
# 405  67.92080   0.0  18.10     0  0.6930  5.683  100.0  1.4254   24  666
# 400  25.04610   0.0  18.10     0  0.6930  5.987  100.0  1.5888   24  666
# 399   9.91655   0.0  18.10     0  0.6930  5.852   77.8  1.5004   24  666
# 414  45.74610   0.0  18.10     0  0.6930  4.519  100.0  1.6582   24  666
# 489   0.18337   0.0  27.74     0  0.6090  5.414   98.3  1.7554    4  711
# 401  14.23620   0.0  18.10     0  0.6930  6.343  100.0  1.5741   24  666
# 385  16.81180   0.0  18.10     0  0.7000  5.277   98.1  1.4261   24  666
# 415  18.08460   0.0  18.10     0  0.6790  6.434  100.0  1.8347   24  666
# 387  22.59710   0.0  18.10     0  0.7000  5.000   89.5  1.5184   24  666
# 416  10.83420   0.0  18.10     0  0.6790  6.782   90.8  1.8195   24  666
# 490   0.20746   0.0  27.74     0  0.6090  5.093   98.0  1.8226    4  711
# ...

# %%
df.sort_values('MEDV',ascending=False) #Set 2 Question 3
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 283   0.01501  90.0   1.21     1  0.4010  7.923   24.8  5.8850    1  198
# 225   0.52693   0.0   6.20     0  0.5040  8.725   83.0  2.8944    8  307
# 369   5.66998   0.0  18.10     1  0.6310  6.683   96.8  1.3567   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016   97.5  1.2024   24  666
# 371   9.23230   0.0  18.10     0  0.6310  6.216  100.0  1.1691   24  666
# 372   8.26725   0.0  18.10     1  0.6680  5.875   89.6  1.1296   24  666
# 186   0.05602   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193
# 204   0.02009  95.0   2.68     0  0.4161  8.034   31.9  5.1180    4  224
# 257   0.61154  20.0   3.97     0  0.6470  8.704   86.9  1.8010    5  264
# 195   0.01381  80.0   0.46     0  0.4220  7.875   32.0  5.6484    4  255
# 166   2.01019   0.0  19.58     0  0.6050  7.929   96.2  2.0459    5  403
# 163   1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# ...

# %%
df.rename(columns={'CAT.MEDV':'MEDV.CAT'},inplace=True) #Set 2 Question 4

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df[df['RM']>=5] #Set 2 Question 5
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df.sample(n=10) #Set 2 Question 6
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 37   0.08014   0.0   5.96     0  0.499  5.850  41.5  3.9342    5  279
# 306  0.07503  33.0   2.18     0  0.472  7.420  71.9  3.0992    7  222
# 307  0.04932  33.0   2.18     0  0.472  6.849  70.3  3.1827    7  222
# 176  0.07022   0.0   4.05     0  0.510  6.020  47.2  3.5549    5  296
# 120  0.06899   0.0  25.65     0  0.581  5.870  69.7  2.2577    2  188
# 358  5.20177   0.0  18.10     1  0.770  6.127  83.4  2.7227   24  666
# 62   0.11027  25.0   5.13     0  0.453  6.456  67.8  7.2255    8  284
# 363  4.22239   0.0  18.10     1  0.770  5.803  89.0  1.9047   24  666
# 149  2.73397   0.0  19.58     0  0.871  5.597  94.9  1.5257    5  403
#
#      PTRATIO  LSTAT  MEDV  MEDV.CAT
# 504     21.0   6.48  22.0         0
# 37      19.2   8.77  21.0         0
# 306     18.4   6.47  33.4         1
# 307     18.4   7.53  28.2         0
# ...

# %%
df.sample(frac=0.6) #Set 2 Question 7
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD  TAX  \
# 105   0.13262   0.0   8.56     0  0.5200  5.851   96.7  2.1069    5  384
# 502   0.04527   0.0  11.93     0  0.5730  6.120   76.7  2.2875    1  273
# 163   1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# 199   0.03150  95.0   1.47     0  0.4030  6.975   15.3  7.6534    3  402
# 162   1.83377   0.0  19.58     1  0.6050  7.802   98.2  2.0407    5  403
# 98    0.08187   0.0   2.89     0  0.4450  7.820   36.9  3.4952    2  276
# 120   0.06899   0.0  25.65     0  0.5810  5.870   69.7  2.2577    2  188
# 118   0.13058   0.0  10.01     0  0.5470  5.872   73.1  2.4775    6  432
# 286   0.01965  80.0   1.76     0  0.3850  6.230   31.5  9.0892    1  241
# 268   0.54050  20.0   3.97     0  0.5750  7.470   52.6  2.8720    5  264
# 317   0.24522   0.0   9.90     0  0.5440  5.782   71.7  4.0317    4  304
# 198   0.03768  80.0   1.52     0  0.4040  7.274   38.3  7.3090    2  329
# ...

# %%
df['TAX_CESS']=0.02*df['TAX'] #Set 2 Question 8

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
df['RM'][df['RM']>=5].count() #Set 2 Question 9
# Out:
# 491

# %%
df['RAD'].nunique()  #Set 2 Question 10
# Out:
# 9
